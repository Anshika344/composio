# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshika344/composio/blob/master/basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #demo for uploading datasets

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
print("hello i'm new to py")
# Out:
# hello i'm new to py

# %%
print('hello python')
# Out:
# hello python

# %% [markdown]
# #print function

# %%
print(8)
# Out:
# 8

# %%
print("hello" + " world")
# Out:
# hello world

# %%
print ("hello" + "world")
# Out:
# helloworld

# %%
print('heyyyy')
# Out:
# heyyyy

# %%
print(9+4)
# Out:
# 13

# %% [markdown]
# #Basic Data Types
#
#
# 1.   int
# 2.   flaot
# 3.   string , str

# %%
type(00)
# Out:
# int

# %%
type(8.5)
# Out:
# float

# %%
type('hey')
# Out:
# str

# %% [markdown]
# #constants and variables

# %%
my_name = "Anshika"
print(my_name)
# Out:
# Anshika

# %%
my_name = "Tannu"
print(my_name)
# Out:
# Tannu

# %%
name1, name2, name3 = "anshika", "tannu", "lolo"
print(name1)
print(name2)
print(name3)
# Out:
# anshika
# tannu
# lolo

# %%
x = y = z = 91
print(x)
print(y)
print(z)
# Out:
# 91
# 91
# 91

# %% [markdown]
# #Input Funcion

# %%
number_1 = input("enter the first number: ")
number_2 = input("enter the second number: ")

sum = number_1 + number_2
print(sum)
# it concatenate the number assuming it as a str as type is not defined
# Out:
# enter the first number: 89
# enter the second number: 89
# 8989

# %%
number_1 = int(input("enter the first number: "))
number_2 = int(input("enter the second number: "))
sum = number_1 + number_2
print(sum)
#we have mentioned the data type int that's why it added the number regardless of concatenate it.
# Out:
# enter the first number: 23
# enter the second number: 23
# 46

# %%
#changing the data type of input

num = 1
print(float(num))
# Out:
# 1.0

# %%
str = 'a'
print(int(str))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2038390903.py in <cell line: 0>()
#       1 x = 'a'
# ----> 2 print(int(x))
#
# ValueError: invalid literal for int() with base 10: 'a'

# %% [markdown]
# #Integers

# %%
a = 1
print(a)
# Out:
# 1

# %%
type(a)
# Out:
# int

# %%
#floating num
b= 3.4
print(b)
# Out:
# 3.4

# %%
type(b)
# Out:
# float

# %%
#complex numbers
c = 4 + 4j
print(c)
type(c)
# Out:
# (4+4j)
# complex

# %% [markdown]
# conversion of one data type to another

# %%
#int  to float
x = 22
print(x)
type(x)
# Out:
# 22
# int

# %%
y = float(x)
print(y)
type(y)
# Out:
# 22.0
# float

# %%
#float to int
i = 33.3
print(i)
type(i)
# Out:
# 33.3
# float

# %%
j = int(i)
print(j)
type(j)
# Out:
# 33
# int

# %% [markdown]
# BOOLEAN

# %%
a = True
print(a)
type(a)
 #in boolean true and false is pre defined so it should start with uppercase else it will give an error
# Out:
# True
# bool

# %%
b = False
print(b)
type(b)
# Out:
# False
# bool

# %%
a = 5 > 9
print(a)
type(a)
# Out:
# False
# bool

# %%
b = 8 > 6
print(b)
type(b)
# Out:
# True
# bool

# %% [markdown]
# string

# %%
print("machine learning")
print('machine learning')
#we can use both single and double quotes for simple string
# Out:
# machine learning
# machine learning

# %%
my_string = "Anshika"
print(my_string)
type(my_string)
# Out:
# Anshika
# str

# %%
print("Hello " * 5)
# Out:
# Hello Hello Hello Hello Hello

# %% [markdown]
#  **slicing**
#
#  means removing

# %%
my_string = "education"

# %%
print(my_string[1:7]) # index 1 to 7 means from index 1 to 7-1 and it starts with index 0
# Out:
# ducati

# %%
print(my_string[0:8:3])
# Out:
# eci

# %% [markdown]
# **concatenation**
# joining two words

# %%
word1 = "Anshika "
word2 = "Gupta"
print(word1 + word2)
# Out:
# Anshika Gupta
