# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshika344/composio/blob/master/if_else_statement_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Simple if else statement

# %%
a = 34
b =43

if(a>b):
  print('a is greater than b')
else:
  print('b is greatest')
# Out:
# b is greatest

# %%
a = int(input('enter the first number: '))
b= int(input('enter the second number:'))

if(a>b):
  print('a is greatest')
else:
  print('b is greatest')
# Out:
# enter the first number: 35
# enter the second number:22
# a is greatest

# %% [markdown]
# if elif else statement

# %%
a = 20
b = 25
c = 15

if(b<a>c):
  print('a is greatest')
elif(a<b>c):
  print('b is greatest')
else:
  print('c is greatest')
# Out:
# b is greatest

# %% [markdown]
# Nested if statement

# %%
a = 20
b = 45
c= 50

if(a>b):
  if(a>c):
    print('a is greattest')
  else:
   print('c is greatest')
else:
  if(b>c):
    print('b is greatest')
  else:
    print('c is greatest')
# Out:
# c is greatest
